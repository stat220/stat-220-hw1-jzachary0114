# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Assignments/Stat_220_HW1.ipynb)

# %% [markdown]
# **Problem 1**. Give an example of a variable that is (a) categorical; (b) quantitative; (c) discrete; (d) continuous.

# %% [markdown]
# a.) color
# b.) height
# c.) number of students in a classroom
# d.) temperature

# %% [markdown]
# **Problem 2**. Analyze the Carbon_West data file using the following code.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
carbon_west = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Carbon_West.dat")

# %% [markdown]
# Part a. Construct a histogram of CO2 emissions.

# %%
carbon_west.head(10)
# Out:
#       Nation   CO2
# 0    Albania   2.0
# 1  Australia  15.4
# 2    Austria   6.9
# 3    Belgium   8.3
# 4     Bosnia   6.2
# 5   Bulgaria   5.9
# 6     Canada  15.1
# 7    Croatia   4.0
# 8     Cyprus   5.3
# 9      Czech   9.2

# %%
plt.hist(carbon_west["CO2"], edgecolor="black")
plt.title("Histogram of CO2 Emissions")
plt.xlabel("CO2 Emissions")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Part b. Find the mean, median, and standard deviation.

# %%
mean_value = np.mean(carbon_west["CO2"])
median_value = np.median(carbon_west["CO2"])
std_value = np.std(carbon_west["CO2"])

print("Mean:", mean_value)
print("Median:", median_value)
print("Standard Deviation:", std_value)
# Out:
# Mean: 6.717142857142858
# Median: 5.9
# Standard Deviation: 3.3086454469884727

# %% [markdown]
# **Problem 3**. Read in the murder data set using the following code. The variable murder is the murder rate (per 100,000 population) for each state in the U.S. in 2017 according to the FBI Uniform Crime Reports. At first, do not use the observation for D.C. (DC).

# %%
murders = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Murder.dat")

# %%
murders_no_dc = murders[murders["state"] != "DC"]
murders_no_dc.head(51)
# Out:
#    state  murder
# 0     AK     8.4
# 1     AL     8.3
# 2     AR     8.6
# 3     AZ     5.9
# 4     CA     4.6
# 5     CO     3.9
# 6     CT     2.8
# 7     DE     5.6
# 8     FL     5.0
# 9     GA     6.7
# 10    HI     2.7
# 11    ID     1.9
# 12    IL     7.8
# 13    IN     6.0
# 14    IO     3.3
# 15    KS     5.5
# 16    KY     5.9
# 17    LA    12.4
# 18    MA     2.5
# 19    MD     9.0
# 20    ME     1.7
# 21    MI     5.7
# 22    MN     2.0
# 23    MO     9.8
# 24    MS     8.2
# 25    MT     3.9
# 26    NC     5.8
# 27    ND     1.3
# 28    NE     2.2
# 29    NH     1.0
# 30    NJ     3.6
# 31    NM     7.1
# 32    NV     2.3
# 33    NY     2.8
# 34    OH     6.1
# 35    OK     6.2
# 36    OR     2.5
# 37    PA     5.8
# 38    RI     1.9
# 39    SC     7.8
# 40    SD     2.9
# 41    TN     7.8
# 42    TX     5.0
# 43    UT     2.4
# 44    VA     5.3
# 45    VT     2.2
# 46    WA     3.1
# 47    WI     3.2
# 48    WV     4.7
# 49    WY     2.6

# %% [markdown]
# Part a. Find the mean and standard deviation for murders without D.C.

# %%
mean_value = np.mean(murders_no_dc["murder"])
std_value = np.std(murders_no_dc["murder"])

print("Mean w/o DC:", mean_value)
print("Standard Deviation w/o DC:", std_value)
# Out:
# Mean w/o DC: 4.874
# Standard Deviation w/o DC: 2.560297638947472

# %% [markdown]
# Part b. Find the five-number  summary without D.C.

# %%
min_no_dc = np.min(murders_no_dc["murder"])
q1_no_dc = np.percentile(murders_no_dc["murder"], 25)
median_no_dc = np.median(murders_no_dc["murder"])
q3_no_dc = np.percentile(murders_no_dc["murder"], 75)
max_no_dc = np.max(murders_no_dc["murder"])

print(f"Minimum (no DC): {min_no_dc}")
print(f"1st Quartile (no DC): {q1_no_dc}")
print(f"Median (no DC): {median_no_dc}")
print(f"3rd Quartile (no DC): {q3_no_dc}")
print(f"Maximum (no DC): {max_no_dc}")
# Out:
# Minimum (no DC): 1.0
# 1st Quartile (no DC): 2.625
# Median (no DC): 4.85
# 3rd Quartile (no DC): 6.175
# Maximum (no DC): 12.4

# %% [markdown]
# Part c. Now include the observation for D.C. and recalculate the mean, median, and five-number summary. What is affected more by this outlier: The mean or the median? The range or the inter-quartile range?

# %%
mean_value = np.mean(murders["murder"])

minimum = np.min(murders["murder"])
q1 = np.percentile(murders["murder"], 25)
median_value = np.median(murders["murder"])
q3 = np.percentile(murders["murder"], 75)
maximum = np.max(murders["murder"])

print("Mean w/ DC:", mean_value)
print(f"Minimum: {minimum}")
print(f"1st Quartile: {q1}")
print(f"Median: {median_value}")
print(f"3rd Quartile: {q3}")
print(f"Maximum: {maximum}")

print(f"The mean is affected more by the outlier.")
print(f"The range is affected more by the outlier.")
# Out:
# Mean w/ DC: 5.252941176470588
# Minimum: 1.0
# 1st Quartile: 2.6500000000000004
# Median: 5.0
# 3rd Quartile: 6.45
# Maximum: 24.2
# The mean is affected more by the outlier.
# The range is affected more by the outlier.

# %% [markdown]
# **Problem 4**. Read in the Houses data file using the following code.  The variables include price (thousands of dollars), size (square feet), tax bill (dollars), number of bathrooms, number of bedrooms, and whether the house is new (1 = yes, 0 = no) for 100 home sales in Gainesville, Florida. Let
# y = selling price and x = size of home.

# %%
houses = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Houses.dat")
houses.head(10)
# Out:
#    case   price  size  new  taxes  bedrooms  baths
# 0     1  419.85  2048    0   3104         4      2
# 1     2  219.75   912    0   1173         2      1
# 2     3  356.55  1654    0   3076         4      2
# 3     4  300.00  2068    0   1608         3      2
# 4     5  239.85  1477    0   1454         3      3
# 5     6  749.85  3153    1   2997         3      2
# 6     7  398.25  1355    0   4054         3      2
# 7     8  434.85  2075    1   3002         3      2
# 8     9  880.50  3990    0   6627         5      4
# 9    10  105.00  1160    0    320         3      2

# %% [markdown]
# Part a. Construct a scatterplot between square feet and price of a home.

# %%
plt.scatter(houses["size"], houses["price"])
plt.title("Scatterplot of Square Feet vs. Price")
plt.xlabel("Square Feet")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Part b. Find the correlation between the two variables.

# %%
correlation = houses["size"].corr(houses["price"])
print("Correlation:", correlation)
# Out:
# Correlation: 0.8337847885586537

# %% [markdown]
# Part c. Find and plot the regression line on top of the scatterplot.

# %%
x = houses[["size"]]
y = houses["price"]

model = LinearRegression()
model.fit(x, y)
slope = model.coef_[0]
intercept = model.intercept_

plt.scatter(x, y, alpha=0.7, label="Scatterplot")
plt.plot(x, model.predict(x), color="red", label="Regression Line")
plt.legend()
plt.title("Scatterplot of Square Feet vs. Price")
plt.xlabel("Square Feet")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Part d. Create a side by side boxplot of price comparing homes that are new and homes that are not new.

# %%
houses.boxplot(column="price", by="new", vert=False, grid=False)
plt.title("Boxplot of Price by Newness")
plt.xlabel("Price")
plt.ylabel("New")
plt.show()

# %% [markdown]
# Part e. What is the relationship between size and price.  Justify your answer using the plots created. Do the same for the relationship between price and whether or not a house is new, again using the plot to justify your answer.

# %% [markdown]
# Generally, the bigger the house is, the more expensive it is. This can be viewed in the scatter plot with the linear regression line. There is a clear correlation between square feet and price.
#
# We can see according the the box plots that new houses are more expensive than houses that aren't new. The median price for an old house is right around 200 thousand, while the median price for a new house is between 400 and 500 thousand.

# %% [markdown]
# **Problem 5**. Using the Happy data file read in by the following code. Construct the contingency table relating marital status and happiness.

# %%
happy = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Happy.dat")
happy.head(10)
# Out:
#    subject happiness marital gender
# 0        1   1     1    male    NaN
# 1        2   1     1    male    NaN
# 2        3   1     1    male    NaN
# 3        4   1     1    male    NaN
# 4        5   1     1    male    NaN
# 5        6   1     1    male    NaN
# 6        7   1     1    male    NaN
# 7        8   1     1    male    NaN
# 8        9   1     1    male    NaN
# 9       10   1     1    male    NaN

# %%
pd.crosstab(happy["marital"], happy["happiness"])
# Out:
# happiness    1  1     1  1     2  1     3    2  2     1  2     2  2     3  \
# marital
# fe         348        0        0        0  642        0        0        0
# fem          0        5        0        0    0        0        0        0
# mal          0      107       33       56    0      229      114      210
# male         0       99        0        0    0        0        0        0
#
# happiness    3  3     1  3     2  3     3
# marital
# fe         153        0        0        0
# fem          0        0        0        0
# mal          0       33       45       68
# male         0        0        0        0

# %%
pd.crosstab(happy["marital"], happy["happiness"], normalize="index")
# Out:
# happiness         1   1     1   1     2  1     3        2   2     1   2     2  \
# marital
# fe         0.304462  0.000000  0.000000  0.00000  0.56168  0.000000  0.000000
# fem        0.000000  1.000000  0.000000  0.00000  0.00000  0.000000  0.000000
# mal        0.000000  0.119553  0.036872  0.06257  0.00000  0.255866  0.127374
# male       0.000000  1.000000  0.000000  0.00000  0.00000  0.000000  0.000000
#
# happiness   2     3         3   3     1   3     2   3     3
# marital
# fe         0.000000  0.133858  0.000000  0.000000  0.000000
# fem        0.000000  0.000000  0.000000  0.000000  0.000000
# mal        0.234637  0.000000  0.036872  0.050279  0.075978
# male       0.000000  0.000000  0.000000  0.000000  0.000000
